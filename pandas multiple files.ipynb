# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %%
inner_merged_df = a_df.merge(b_df, on='Country')
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %%
left_merged_df = a_df.merge(b_df, on='Country', how='left')
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %%
right_merged_df = a_df.merge(b_df, on='Country', how='right')
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %%
outer_merged_df = a_df.merge(b_df, on='Country', how='outer')
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %%
outer_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
# Country           5 non-null object
# Population (M)    4 non-null float64
# Capital           4 non-null object
# HDI               4 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 200.0+ bytes

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
aa_df.join(bb_df, how='inner')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916

# %%
aa_df.join(bb_df, how='right')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926

# %%
aa_df.join(bb_df, how='outer')
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %%
countries_df = pd.read_csv('dictionary.csv')
countries_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
summer_df = pd.read_csv('summer.csv')
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer_df.rename(columns={"Country": "Code"}, inplace=True)
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
winter_df = pd.read_csv('winter.csv')
winter_df.rename(columns={"Country": "Code"}, inplace=True)
winter_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer_countries_df = summer_df.merge(countries_df, on="Code")
summer_countries_df["Season"] = "Summer"
summer_countries_df.head()
# Out:
#    Year    City      Sport Discipline           Athlete Code Gender  \
# 0  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3  1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4  1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
#
#              Event   Medal  Country  Population  GDP per Capita  Season
# 0   100M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 1  1200M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 2             100M  Bronze  Hungary   9844686.0     12363.54346  Summer
# 3             800M  Silver  Hungary   9844686.0     12363.54346  Summer
# 4         Marathon  Bronze  Hungary   9844686.0     12363.54346  Summer

# %%
winter_countries_df = winter_df.merge(countries_df, on="Code")
winter_countries_df["Season"] = "Winter"
winter_countries_df.head()
# Out:
#    Year    City      Sport Discipline           Athlete Code Gender  \
# 0  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3  1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4  1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
#
#              Event   Medal  Country  Population  GDP per Capita  Season
# 0   100M Freestyle    Gold  Hungary   9844686.0     12363.54346  Winter
# 1  1200M Freestyle    Gold  Hungary   9844686.0     12363.54346  Winter
# 2             100M  Bronze  Hungary   9844686.0     12363.54346  Winter
# 3             800M  Silver  Hungary   9844686.0     12363.54346  Winter
# 4         Marathon  Bronze  Hungary   9844686.0     12363.54346  Winter

# %%
all_df = pd.concat([summer_countries_df, winter_countries_df], axis="index", sort=False)
all_df.tail()
# Out:
#        Year    City      Sport Discipline           Athlete Code Gender  \
# 25737  2012  London  Athletics  Athletics   BARRONDO, Erick  GUA    Men
# 25738  2012  London  Athletics  Athletics     JAMES, Kirani  GRN    Men
# 25739  2012  London  Athletics  Athletics       AMOS, Nijel  BOT    Men
# 25740  2012  London    Sailing    Sailing  KONTIDES, Pavlos  CYP    Men
# 25741  2012  London  Taekwondo  Taekwondo    OBAME, Anthony  GAB    Men
#
#            Event   Medal    Country  Population  GDP per Capita  Season
# 25737  20KM Walk  Silver  Guatemala  16342897.0     3903.478856  Winter
# 25738       400M    Gold    Grenada    106825.0     9212.020352  Winter
# 25739       800M  Silver   Botswana   2262485.0     6360.138220  Winter
# 25740      Laser  Silver     Cyprus   1165300.0    23242.840069  Winter
# 25741    + 80 KG  Silver      Gabon   1725292.0     8266.445605  Winter

# %%
all_count_df = all_df[all_df["Year"] >= 1984] \
    .groupby(["Country"]) \
    .count()[["Medal"]] \
    .sort_values(by="Medal", ascending=False)
all_count_df.head(10)
# Out:
#                 Medal
# Country
# United States    4174
# Australia        1752
# China            1614
# Germany          1570
# Russia           1536
# United Kingdom   1032
# Korea, South     1000
# Italy             972
# France            964
# Netherlands       952

# %%
all_count_df.head(10).plot(kind="bar")

# %%
season_count_df = all_df.groupby(["Country", "Season"])["Medal"].count().unstack()

# %%
season_count_df.fillna(0, inplace=True)

# %%
season_count_df["Summer"] = season_count_df["Summer"].astype(int)
season_count_df["Winter"] = season_count_df["Winter"].astype(int)
season_count_df.head(10)
# Out:
# Season       Summer  Winter
# Country
# Afghanistan       2       2
# Algeria          15      15
# Argentina       259     259
# Armenia          11      11
# Australia      1189    1189
# Austria         146     146
# Azerbaijan       26      26
# Bahamas          27      27
# Bahrain           1       1
# Barbados          1       1

# %%
season_count_df["Total"] = all_count_df

# %%
season_count_df.head(10)
# Out:
# Season       Summer  Winter   Total
# Country
# Afghanistan       2       2     4.0
# Algeria          15      15    30.0
# Argentina       259     259   346.0
# Armenia          11      11    22.0
# Australia      1189    1189  1752.0
# Austria         146     146    56.0
# Azerbaijan       26      26    52.0
# Bahamas          27      27    46.0
# Bahrain           1       1     2.0
# Barbados          1       1     2.0

# %%
season_count_df.sort_values(by="Total", ascending=False)[["Summer", "Winter"]].head(10).plot(kind="bar")
